# %%
import pandas as pd
import seaborn 
import matplotlib.pyplot as plt

# %%
iris_datasets=pd.read_csv("iris.csv")

# %%
iris_datasets
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
iris_datasets.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
iris_datasets=iris_datasets[['sepal.length', 'sepal.width', 'petal.length', 'petal.width']]
iris_datasets.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris_datasets.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b0bfd_row0_col0, #T_b0bfd_row1_col1, #T_b0bfd_row2_col2, #T_b0bfd_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b0bfd_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b0bfd_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_b0bfd_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_b0bfd_row1_col0, #T_b0bfd_row1_col2, #T_b0bfd_row1_col3, #T_b0bfd_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b0bfd_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_b0bfd_row2_col3, #T_b0bfd_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_b0bfd_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_b0bfd_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0bfd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
plt.figure(figsize=(8,8))
seaborn.heatmap(iris_datasets.corr(),annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
iris_datasets_pairplot=iris_datasets.dropna()
iris_datasets.to_excel
seaborn.pairplot(iris_datasets_pairplot,height=1.5)

# %%
import matplotlib.pyplot as plt 
plt.imshow(iris_datasets.corr(), cmap='coolwarm',interpolation ='none')
plt.colorbar()
plt.xticks(range(len(iris_datasets.columns)), iris_datasets.columns, rotation=90)
plt.yticks(range(len(iris_datasets.columns)), iris_datasets.columns)
plt.gcf().set_size_inches(8,8)

labels=iris_datasets.corr().values
for y in range(labels.shape[0]):
    for x in range(labels.shape[1]):
        plt.text(x,y,'{:.2f})'.format(labels[y,x]),ha='center',va='center',color='white')
